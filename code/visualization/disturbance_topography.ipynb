# %%
import geopandas as gpd
import rioxarray

# %%
import matplotlib.pyplot as plt

# %%
da = rioxarray.open_rasterio('/home/jovyan/data-store/data/iplant/home/shared/earthlab/forest_carbon_codefest/Team_outputs/Team3/NAFD_disturbance/conus_max_intensity_30m_co.tiff', masked=True)
fig, ax = plt.subplots(figsize=(12, 7))
image = (da.squeeze()/100).plot.imshow(ax=ax)
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize='medium') 
plt.title('maximum disturbance intensity/severity (1986-2015)')
# Out:
# Text(0.5, 1.0, 'maximum disturbance intensity/severity (1986-2015)')

# %%
da = rioxarray.open_rasterio('/home/jovyan/data-store/data/iplant/home/shared/earthlab/forest_carbon_codefest/Team_outputs/Team3/NAFD_disturbance/conus_count_intensity_500m_co_reproj.tif', masked=True)
# da1 = da.where(da != 0)
fig, ax = plt.subplots(figsize=(12, 7))
image = (da.squeeze()-1).plot.imshow(ax=ax,cmap = 'viridis_r')
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize='medium') 
plt.title('disturbance count (1986-2015)')
# Out:
# Text(0.5, 1.0, 'disturbance count (1986-2015)')

# %%
da = rioxarray.open_rasterio('/home/jovyan/data-store/data/iplant/home/shared/earthlab/forest_carbon_codefest/Team_outputs/Team3/topo/co_DEM_reproj.tif', masked=True)
# da1 = da.where(da != 0)
fig, ax = plt.subplots(figsize=(12, 7))
image = (da.squeeze()).plot.imshow(ax=ax,cmap = 'Greys_r')
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize='medium') 
plt.title('DEM')
# Out:
# Text(0.5, 1.0, 'DEM')

# %%
import numpy as np

# %%
da = rioxarray.open_rasterio('/home/jovyan/data-store/data/iplant/home/shared/earthlab/forest_carbon_codefest/Team_outputs/Team3/topo/co_slope_reproj.tif', masked=True)
# da1 = da.where(da != 0)
fig, ax = plt.subplots(figsize=(12, 7))
image = da.squeeze().plot.imshow(ax=ax,cmap = 'gist_earth')
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize='medium') 
plt.title('Slope (Degree)')
# Out:
# Text(0.5, 1.0, 'Slope (Degree)')

# %%
da.squeeze().values.min()
# Out:
# nan

# %%
da.squeeze().values.max()
# Out:
# nan
